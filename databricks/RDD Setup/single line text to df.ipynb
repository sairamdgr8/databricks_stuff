# %%
# importing Spark Libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
#intializing the spark session
spark=SparkSession.builder.appName("reading the text line").getOrCreate()

# %%
raw_rdd=spark.sparkContext.textFile("/FileStore/tables/singleline.txt")
raw_rdd_1=raw_rdd.collect()
raw_rdd_1
# Out:
# Out[3]: ['sai#EY#soumyadeep#TCS#pramod#ameriprse#rags#KPMG']

# %%
# spliting the RDD
for i in raw_rdd_1:
  normailized_rdd=i.split("#")
# picking the respective indexes for columns creation
e_name=normailized_rdd[::2]
e_org=normailized_rdd[1::2]
print(e_name,e_org)
# Out:
# ['sai', 'soumyadeep', 'pramod', 'rags'] ['EY', 'TCS', 'ameriprse', 'KPMG']

# %%
mydict=dict(zip(e_name,e_org))
mydict
# Out:
# Out[5]: {'sai': 'EY', 'soumyadeep': 'TCS', 'pramod': 'ameriprse', 'rags': 'KPMG'}

# %%
e=[]
for i,j in mydict.items():
  e.append([i,j])
print(e)
# Out:
# [['sai', 'EY'], ['soumyadeep', 'TCS'], ['pramod', 'ameriprse'], ['rags', 'KPMG']]

# %%
### create a Dataframe
df=spark.createDataFrame(data=e,schema=["emp_name","emp_organization"])
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>emp_organization</th></tr></thead><tbody><tr><td>sai</td><td>EY</td></tr><tr><td>soumyadeep</td><td>TCS</td></tr><tr><td>pramod</td><td>ameriprse</td></tr><tr><td>rags</td><td>KPMG</td></tr></tbody></table></div>
